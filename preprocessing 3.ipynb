# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Extracting features of 2018,2019,2020,2021 movies from Wikipedia

# %%
link_1 = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
link_2 = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
link_3 = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"
link_4 = "https://en.wikipedia.org/wiki/List_of_American_films_of_2021"

# %%
pd.read_html(link_3, header=0)[3]# I need only the relevant tables from this
# Out:
#      Opening  Opening.1                                   Title  \
# 0    JANUARY          3                              The Grudge
# 1    JANUARY         10                              Underwater
# 2    JANUARY         10                             Like a Boss
# 3    JANUARY         10                           Three Christs
# 4    JANUARY         10                       Inherit the Viper
# 5    JANUARY         10                              The Sonata
# 6    JANUARY         10      The Murder of Nicole Brown Simpson
# 7    JANUARY         17                       Bad Boys for Life
# 8    JANUARY         17                                Dolittle
# 9    JANUARY         17                       A Fall from Grace
# 10   JANUARY         24                           The Gentlemen
# 11   JANUARY         24                             The Turning
# 12   JANUARY         24                   The Last Full Measure
# 13   JANUARY         24                         The Night House
# ...

# %%
df=pd.DataFrame()
my_df=pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
def extract(link,df):
    if(not df.empty):
        df=df[0:0]
    # This conditional statement is needed because for 2020 and 2021 movies link the tables need to extracted from index 3
    if (link==link_3):
        df1 = pd.read_html(link, header=0)[3]
        df2 = pd.read_html(link, header=0)[4]
        df3 = pd.read_html(link, header=0)[5]
        df4 = pd.read_html(link, header=0)[6]
        df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
        return df
    if (link==link_4):
        df1 = pd.read_html(link, header=0)[3]
        df2 = pd.read_html(link, header=0)[4]
        df3 = pd.read_html(link, header=0)[5]
        df4 = pd.read_html(link, header=0)[6]
        df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
        return df
    else:
        df1 = pd.read_html(link, header=0)[2]
        df2 = pd.read_html(link, header=0)[3]
        df3 = pd.read_html(link, header=0)[4]
        df4 = pd.read_html(link, header=0)[5]
        

    df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
    return df

# %% [markdown]
# #### Pass the link variable in this function and subsequent cells

# %%
#pass all the link variables one by one to see the how the processing is done for each year 
df=extract(link_4,df)

# %%
df
# Out:
#       Opening  Opening.1                                     Title  \
# 0     JANUARY          1                       Shadow in the Cloud
# 1     JANUARY         13                           The White Tiger
# 2     JANUARY         14                               Locked Down
# 3     JANUARY         15                                   The Dig
# 4     JANUARY         15                          Outside the Wire
# ..        ...        ...                                       ...
# 315  DECEMBER         22                  The Matrix Resurrections
# 316  DECEMBER         22                                    Sing 2
# 317  DECEMBER         22                            The King's Man
# 318  DECEMBER         25  American Underdog: The Kurt Warner Story
# 319  DECEMBER         31                                    Cyrano
#
#                                     Production company  \
# 0                               Vertical Entertainment
# ...

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = 'YOUR_API_KEY'

from tmdbv3api import Movie

# %%
def genre_preprocessing(df):
    tmdb_movie = Movie()
    def get_genre(x):
        genres = []
        result = tmdb_movie.search(x)
        if not result:
          return np.NaN
        else:
          movie_id = result[0].id
          response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
          data_json = response.json()
          if data_json['genres']:
              genre_str = " " 
              for i in range(0,len(data_json['genres'])):
                  genres.append(data_json['genres'][i]['name'])
              return genre_str.join(genres)
          else:
              return np.NaN

    df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
genre_preprocessing(df)

# %%
df
# Out:
#       Opening  Opening.1                                     Title  \
# 0     JANUARY          1                       Shadow in the Cloud
# 1     JANUARY         13                           The White Tiger
# 2     JANUARY         14                               Locked Down
# 3     JANUARY         15                                   The Dig
# 4     JANUARY         15                          Outside the Wire
# ..        ...        ...                                       ...
# 315  DECEMBER         22                  The Matrix Resurrections
# 316  DECEMBER         22                                    Sing 2
# 317  DECEMBER         22                            The King's Man
# 318  DECEMBER         25  American Underdog: The Kurt Warner Story
# 319  DECEMBER         31                                    Cyrano
#
#                                     Production company  \
# 0                               Vertical Entertainment
# ...

# %%
df = df[['Title','Cast and crew','genres']]

# %%
df
# Out:
#                                         Title  \
# 0                         Shadow in the Cloud
# 1                             The White Tiger
# 2                                 Locked Down
# 3                                     The Dig
# 4                            Outside the Wire
# ..                                        ...
# 315                  The Matrix Resurrections
# 316                                    Sing 2
# 317                            The King's Man
# 318  American Underdog: The Kurt Warner Story
# 319                                    Cyrano
#
#                                          Cast and crew  \
# 0    Roseanne Liang (director/screenplay); Max Land...
# 1    Ramin Bahrani (director/screenplay); Adarsh Go...
# 2    Doug Liman (director); Steven Knight (screenpl...
# 3    Simon Stone (director); Moira Buffini (screenp...
# 4    Mikael Håfström (director); Rob Yescombe, Rowa...
# ..                                                 ...
# ...

# %%
df['Cast and crew'][0]
# Out:
# 'Roseanne Liang (director/screenplay); Max Landis (screenplay); Chloë Grace Moretz, Taylor John Smith, Beulah Koale, Callan Mulvey, Nick Robinson'

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df['director_name'] = df['Cast and crew'].map(lambda x: get_director(x))
# Out:
# <ipython-input-95-d27a6bf8d89f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['director_name'] = df['Cast and crew'].map(lambda x: get_director(x))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df['actor_1_name'] = df['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# <ipython-input-97-603fbe2dd9d4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['actor_1_name'] = df['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df['actor_2_name'] = df['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# <ipython-input-99-5ea8f0c1ebc3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['actor_2_name'] = df['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df['actor_3_name'] = df['Cast and crew'].map(lambda x: get_actor3(x))
# Out:
# <ipython-input-101-fc2fe3c8d5ef>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['actor_3_name'] = df['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df
# Out:
#                                         Title  \
# 0                         Shadow in the Cloud
# 1                             The White Tiger
# 2                                 Locked Down
# 3                                     The Dig
# 4                            Outside the Wire
# ..                                        ...
# 315                  The Matrix Resurrections
# 316                                    Sing 2
# 317                            The King's Man
# 318  American Underdog: The Kurt Warner Story
# 319                                    Cyrano
#
#                                          Cast and crew  \
# 0    Roseanne Liang (director/screenplay); Max Land...
# 1    Ramin Bahrani (director/screenplay); Adarsh Go...
# 2    Doug Liman (director); Steven Knight (screenpl...
# 3    Simon Stone (director); Moira Buffini (screenp...
# 4    Mikael Håfström (director); Rob Yescombe, Rowa...
# ..                                                 ...
# ...

# %%
df = df.rename(columns={'Title':'movie_title'})

# %%
new_df = df.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df
# Out:
#        director_name         actor_1_name       actor_2_name  \
# 0     Roseanne Liang   Chloë Grace Moretz  Taylor John Smith
# 1      Ramin Bahrani        Adarsh Gourav      Rajkummar Rao
# 2         Doug Liman        Anne Hathaway   Chiwetel Ejiofor
# 3        Simon Stone       Carey Mulligan      Ralph Fiennes
# 4    Mikael Håfström       Anthony Mackie       Damson Idris
# ..               ...                  ...                ...
# 315   Lana Wachowski         Keanu Reeves   Carrie-Anne Moss
# 316   Garth Jennings  Matthew McConaughey  Reese Witherspoon
# 317   Matthew Vaughn        Ralph Fiennes     Gemma Arterton
# 318   Erwin brothers         Zachary Levi        Anna Paquin
# 319       Joe Wright       Peter Dinklage      Haley Bennett
#
#               actor_3_name                                     genres  \
# 0             Beulah Koale                          Horror Action War
# 1    Priyanka Chopra Jonas                                Crime Drama
# ...

# %%
new_df['actor_2_name'] = new_df['actor_2_name'].replace(np.nan, 'unknown')
new_df['actor_3_name'] = new_df['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df['movie_title'] = new_df['movie_title'].str.lower()

# %%
new_df['comb'] = new_df['actor_1_name'] + ' ' + new_df['actor_2_name'] + ' '+ new_df['actor_3_name'] + ' '+ new_df['director_name'] +' ' + new_df['genres']

# %%
new_df
# Out:
#        director_name         actor_1_name       actor_2_name  \
# 0     Roseanne Liang   Chloë Grace Moretz  Taylor John Smith
# 1      Ramin Bahrani        Adarsh Gourav      Rajkummar Rao
# 2         Doug Liman        Anne Hathaway   Chiwetel Ejiofor
# 3        Simon Stone       Carey Mulligan      Ralph Fiennes
# 4    Mikael Håfström       Anthony Mackie       Damson Idris
# ..               ...                  ...                ...
# 315   Lana Wachowski         Keanu Reeves   Carrie-Anne Moss
# 316   Garth Jennings  Matthew McConaughey  Reese Witherspoon
# 317   Matthew Vaughn        Ralph Fiennes     Gemma Arterton
# 318   Erwin brothers         Zachary Levi        Anna Paquin
# 319       Joe Wright       Peter Dinklage      Haley Bennett
#
#               actor_3_name                                     genres  \
# 0             Beulah Koale                          Horror Action War
# 1    Priyanka Chopra Jonas                                Crime Drama
# ...

# %%
if(my_df.empty):
    my_df=pd.DataFrame(new_df)
else:
    print("1")
    my_df=my_df.append(new_df,ignore_index=True)
my_df
# Out:
# 1
#            director_name         actor_1_name            actor_2_name  \
# 0           Adam Robitel            Lin Shaye           Angus Sampson
# 1       Lauren Wolkstein        Alex Pettyfer  James Freedson-Jackson
# 2             Simon West       Dominic Cooper          Austin Stowell
# 3       Warwick Thornton          Bryan Brown               Sam Neill
# 4     Jaume Collet-Serra          Liam Neeson            Vera Farmiga
# ...                  ...                  ...                     ...
# 1099      Lana Wachowski         Keanu Reeves        Carrie-Anne Moss
# 1100      Garth Jennings  Matthew McConaughey       Reese Witherspoon
# 1101      Matthew Vaughn        Ralph Fiennes          Gemma Arterton
# 1102      Erwin brothers         Zachary Levi             Anna Paquin
# 1103          Joe Wright       Peter Dinklage           Haley Bennett
#
#                actor_3_name                                     genres  \
# ...

# %% [markdown]
# #### Run the above code uptill here for all the links of movies for the year 2018,2019,2020,2021

# %%
old_df = pd.read_csv('new_data.csv')

# %%
old_df
# Out:
#               director_name          actor_1_name            actor_2_name  \
# 0             James Cameron           CCH Pounder        Joel David Moore
# 1            Gore Verbinski           Johnny Depp           Orlando Bloom
# 2                Sam Mendes       Christoph Waltz            Rory Kinnear
# 3         Christopher Nolan             Tom Hardy          Christian Bale
# 4               Doug Walker           Doug Walker              Rob Walker
# ...                     ...                   ...                     ...
# 5359            Jim Strouse      Jessica Williams            Chris O'Dowd
# 5360            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 5361       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# 5362  Jonathan A. Rosenbaum  Lou Diamond Phillips           Wallace Shawn
# 5363           Ravi Udyawar        Sridevi Kapoor               Sajal Ali
#
#               actor_3_name                           genres  \
# ...

# %%
final_df = old_df.append(my_df,ignore_index=True)

# %%
final_df
# Out:
#           director_name         actor_1_name       actor_2_name  \
# 0         James Cameron          CCH Pounder   Joel David Moore
# 1        Gore Verbinski          Johnny Depp      Orlando Bloom
# 2            Sam Mendes      Christoph Waltz       Rory Kinnear
# 3     Christopher Nolan            Tom Hardy     Christian Bale
# 4           Doug Walker          Doug Walker         Rob Walker
# ...                 ...                  ...                ...
# 6463     Lana Wachowski         Keanu Reeves   Carrie-Anne Moss
# 6464     Garth Jennings  Matthew McConaughey  Reese Witherspoon
# 6465     Matthew Vaughn        Ralph Fiennes     Gemma Arterton
# 6466     Erwin brothers         Zachary Levi        Anna Paquin
# 6467         Joe Wright       Peter Dinklage      Haley Bennett
#
#                actor_3_name                                     genres  \
# 0                 Wes Studi            Action Adventure Fantasy Sci-Fi
# ...

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           4
# movie_title      0
# comb             4
# dtype: int64

# %%
final_df = final_df.dropna(how='any')

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
final_df.to_csv('main_data.csv',index=False)

# %%
df.loc[df['movie_title']=='The Dig'].index[0]
# Out:
# 3

# %% [markdown]
# # The file ends here
